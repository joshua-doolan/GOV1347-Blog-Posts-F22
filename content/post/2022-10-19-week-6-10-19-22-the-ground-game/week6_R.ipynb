# %%
library(tidyverse)
# Out:
# -- Attaching packages --------------------------------------- tidyverse 1.3.2 --
# v ggplot2 3.3.6      v purrr   0.3.4
# v tibble  3.1.8      v dplyr   1.0.10
# v tidyr   1.2.1      v stringr 1.4.1
# v readr   2.1.2      v forcats 0.5.2
# -- Conflicts ------------------------------------------ tidyverse_conflicts() --
# x dplyr::filter() masks stats::filter()
# x dplyr::lag()    masks stats::lag()

# %%
train_df = read_csv("train_races.csv")
# Out:
# Rows: 2181 Columns: 10
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (2): State, state_abb
# dbl (6): raceYear, district_num, RepVotesMajorPercent, national_turnout, dis...
# lgl (2): D_inc, R_inc
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
train_nonexp_df = train_df %>% filter(is.na(train_df$avg_rating))
train_lm = lm(data=train_nonexp_df, formula=RepVotesMajorPercent ~ dist_turnout + R_inc + D_inc)
summary(train_lm)
# Out:
# Call:
# lm(formula = RepVotesMajorPercent ~ dist_turnout + R_inc + D_inc,
#     data = train_nonexp_df)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -49.345  -9.054  -1.233   9.691  52.800
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)    47.200      1.535  30.758   <2e-16 ***
# dist_turnout    4.674      2.077   2.251   0.0245 *
# R_incTRUE      20.649      1.315  15.700   <2e-16 ***
# D_incTRUE     -24.643      1.312 -18.787   <2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 15.23 on 1627 degrees of freedom
#   (49 observations deleted due to missingness)
# Multiple R-squared:  0.6678,	Adjusted R-squared:  0.6672
# F-statistic:  1090 on 3 and 1627 DF,  p-value: < 2.2e-16

# %%
train_expert_df = train_df %>% drop_na()

# %%
exp_lm = lm(data=train_expert_df, formula=RepVotesMajorPercent ~ dist_turnout + R_inc + D_inc + avg_rating)
summary(exp_lm)
# Out:
# Call:
# lm(formula = RepVotesMajorPercent ~ dist_turnout + R_inc + D_inc +
#     avg_rating, data = train_expert_df)
#
# Residuals:
#      Min       1Q   Median       3Q      Max
# -18.3762  -1.7833   0.0669   1.7568  12.8139
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)   35.9403     0.7448  48.254  < 2e-16 ***
# dist_turnout   2.4041     0.8236   2.919  0.00368 **
# R_incTRUE     -0.7000     0.3872  -1.808  0.07124 .
# D_incTRUE      1.3377     0.4578   2.922  0.00364 **
# avg_rating     3.2438     0.1112  29.179  < 2e-16 ***
# ---
# Signif. codes:  0 '***' 0.001 '**' 0.01 '*' 0.05 '.' 0.1 ' ' 1
#
# Residual standard error: 3.183 on 477 degrees of freedom
# Multiple R-squared:  0.7297,	Adjusted R-squared:  0.7274
# F-statistic: 321.9 on 4 and 477 DF,  p-value: < 2.2e-16

# %%
test_df = read_csv("test_races.csv")
# Out:
# Rows: 435 Columns: 8
# -- Column specification --------------------------------------------------------
# Delimiter: ","
# chr (3): state, abb_info, abb-dist
# dbl (3): district, dist_turnout, avg_rating
# lgl (2): R_inc, D_inc
#
# i Use `spec()` to retrieve the full column specification for this data.
# i Specify the column types or set `show_col_types = FALSE` to quiet this message.

# %%
test_nonexp_df = test_df %>% filter(is.na(test_df$avg_rating))
test_expert_df = test_df %>% drop_na()

# %%
predict(train_lm, test_nonexp_df)
# Out:
#        1        2        3        4        5        6        7        8
# 69.71198 69.94119 69.80094 69.95650 49.46442 69.81035 24.54733 25.34627
#        9       10       11       12       13       14       15       16
# 23.99440 70.47358 24.20368 69.70093 69.53773 69.44678 69.83843 69.80676
#       17       18       19       20       21       22       23       24
# 69.50972 69.88412 25.05214 24.68900 70.20603 24.67882 24.56078 24.46835
#       25       26       27       28       29       30       31       32
# 24.88005 24.71673 24.60225 49.06999 49.28840 24.65176 24.57022 24.87385
